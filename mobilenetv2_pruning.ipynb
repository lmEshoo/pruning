# %% [markdown]
# <a href="https://colab.research.google.com/github/lmEshoo/pruning/blob/master/mobilenetv2_pruning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Mobilenetv2 model pruning**

# %% [markdown]
# **Build Model**

# %%
import tensorflow as tf
tf.__version__
# !pip uninstall tensorflow -y
! pip uninstall -y tensorflow
! pip uninstall -y tf-nightly
# !pip install tensorflow==2.1.0
# ! pip install -q -U tensorflow-gpu==1.14.0

! pip install -q tensorflow-model-optimization
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# Uninstalling tensorflow-1.15.0:
#   Successfully uninstalled tensorflow-1.15.0
# WARNING: Skipping tf-nightly as it is not installed.
# Collecting tensorflow==2.1.0
#   Downloading https://files.pythonhosted.org/packages/85/d4/c0cd1057b331bc38b65478302114194bd8e1b9c2bbc06e300935c0e93d90/tensorflow-2.1.0-cp36-cp36m-manylinux2010_x86_64.whl (421.8MB)
#      |████████████████████████████████| 421.8MB 38kB/s
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.1.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.17.5)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.27.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.0.8)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.11.2)
# Collecting tensorboard<2.2.0,>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/d9/41/bbf49b61370e4f4d245d4c6051dfb6db80cec672605c91b1652ac8cc3d38/tensorboard-2.1.1-py3-none-any.whl (3.8MB)
#      |████████████████████████████████| 3.9MB 61.7MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.12.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (0.34.2)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (3.10.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (0.1.8)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (0.8.1)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (0.2.2)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (1.4.1)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.1.0) (0.9.0)
# Collecting tensorflow-estimator<2.2.0,>=2.1.0rc0
#   Downloading https://files.pythonhosted.org/packages/18/90/b77c328a1304437ab1310b463e533fa7689f4bfc41549593056d812fab8e/tensorflow_estimator-2.1.0-py2.py3-none-any.whl (448kB)
#      |████████████████████████████████| 450kB 53.2MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==2.1.0) (2.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.2.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (0.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (2.21.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.0.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.7.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (45.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.3.0)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (2.8)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (0.2.8)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.2.0,>=2.1.0->tensorflow==2.1.0) (0.4.8)
# Installing collected packages: tensorboard, tensorflow-estimator, tensorflow
#   Found existing installation: tensorboard 1.15.0
#     Uninstalling tensorboard-1.15.0:
#       Successfully uninstalled tensorboard-1.15.0
#   Found existing installation: tensorflow-estimator 1.15.1
#     Uninstalling tensorflow-estimator-1.15.1:
#       Successfully uninstalled tensorflow-estimator-1.15.1
# Successfully installed tensorboard-2.1.1 tensorflow-2.1.0 tensorflow-estimator-2.1.0
#      |████████████████████████████████| 102kB 7.4MB/s

# %%
"""
# Reference
- [Inverted Residuals and Linear Bottlenecks Mobile Networks for
   Classification, Detection and Segmentation]
   (https://arxiv.org/abs/1801.04381)
"""

import tensorflow as tf

# Define ReLU6 activation
relu6 = tf.keras.layers.ReLU(6.)

def _conv_block(inputs, filters, kernel, strides):
    """Convolution Block
    This function defines a 2D convolution operation with BN and relu6.

    # Arguments
        inputs: Tensor, input tensor of conv layer.
        filters: Integer, the dimensionality of the output space.
        kernel: An integer or tuple/list of 2 integers, specifying the
            width and height of the 2D convolution window.
        strides: An integer or tuple/list of 2 integers,
            specifying the strides of the convolution along the width and height.
            Can be a single integer to specify the same value for
            all spatial dimensions.

    # Returns
        Output tensor.
    """

    x = tf.keras.layers.Conv2D(filters, kernel, padding='same', strides=strides)(inputs)
    x = tf.keras.layers.BatchNormalization()(x)
    return relu6(x)


def _bottleneck(inputs, filters, kernel, t, s, r=False):
    """Bottleneck
    This function defines a basic bottleneck structure.

    # Arguments
        inputs: Tensor, input tensor of conv layer.
        filters: Integer, the dimensionality of the output space.
        kernel: An integer or tuple/list of 2 integers, specifying the
            width and height of the 2D convolution window.
        t: Integer, expansion factor.
            t is always applied to the input size.
        s: An integer or tuple/list of 2 integers,specifying the strides
            of the convolution along the width and height.Can be a single
            integer to specify the same value for all spatial dimensions.
        r: Boolean, Whether to use the residuals.

    # Returns
        Output tensor.
    """

    tchannel = inputs.shape[-1] * t

    x = _conv_block(inputs, tchannel, (1, 1), (1, 1))

    x = tf.keras.layers.DepthwiseConv2D(kernel, strides=(s, s), depth_multiplier=1, padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = relu6(x)

    x = tf.keras.layers.Conv2D(filters, (1, 1), strides=(1, 1), padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)

    if r:
        x = tf.keras.layers.add([x, inputs])
    return x


def _inverted_residual_block(inputs, filters, kernel, t, strides, n):
    """Inverted Residual Block
    This function defines a sequence of 1 or more identical layers.

    # Arguments
        inputs: Tensor, input tensor of conv layer.
        filters: Integer, the dimensionality of the output space.
        kernel: An integer or tuple/list of 2 integers, specifying the
            width and height of the 2D convolution window.
        t: Integer, expansion factor.
            t is always applied to the input size.
        s: An integer or tuple/list of 2 integers,specifying the strides
            of the convolution along the width and height.Can be a single
            integer to specify the same value for all spatial dimensions.
        n: Integer, layer repeat times.
    # Returns
        Output tensor.
    """

    x = _bottleneck(inputs, filters, kernel, t, strides)

    for i in range(1, n):
        x = _bottleneck(x, filters, kernel, t, 1, True)

    return x


def MobileNetV2(input_shape, k, plot_model=False):
    """MobileNetv2
    This function defines a MobileNetv2 architecture.

    # Arguments
        input_shape: An integer or tuple/list of 3 integers, shape
            of input tensor.
        k: Integer, number of classes.
        plot_model: Boolean, whether to plot model architecture or not
    # Returns
        MobileNetv2 model.
    """

    inputs = tf.keras.layers.Input(shape=input_shape, name='input')
    x = _conv_block(inputs, 32, (3, 3), strides=(2, 2))

    x = _inverted_residual_block(x, 16, (3, 3), t=1, strides=1, n=1)
    x = _inverted_residual_block(x, 24, (3, 3), t=6, strides=2, n=2)
    x = _inverted_residual_block(x, 32, (3, 3), t=6, strides=2, n=3)
    x = _inverted_residual_block(x, 64, (3, 3), t=6, strides=2, n=4)
    x = _inverted_residual_block(x, 96, (3, 3), t=6, strides=1, n=3)
    x = _inverted_residual_block(x, 160, (3, 3), t=6, strides=2, n=3)
    x = _inverted_residual_block(x, 320, (3, 3), t=6, strides=1, n=1)

    x = _conv_block(x, 1280, (1, 1), strides=(1, 1))
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Reshape((1, 1, 1280))(x)
    x = tf.keras.layers.Dropout(0.3, name='Dropout')(x)
    x = tf.keras.layers.Conv2D(k, (1, 1), padding='same')(x)
    x = tf.keras.layers.Activation('softmax', name='final_activation')(x)
    output = tf.keras.layers.Reshape((k,), name='output')(x)
    model = tf.keras.models.Model(inputs, output)
    model.summary()
    if plot_model:
        tf.keras.utils.plot_model(model, to_file='model.png', show_shapes=True)

    return model

# %%
import cv2
import os
from keras.datasets import cifar100



train = 'train//'
val = 'validation//'

(X_train, y_train), (X_test, y_test) = cifar100.load_data(label_mode='fine')

for i in range(len(X_train)):
    x = X_train[i]
    y = y_train[i]
    path = train + str(y[0])
    x = cv2.resize(x, (224, 224), interpolation=cv2.INTER_CUBIC)
    if not os.path.exists(path):
        os.makedirs(path)
    cv2.imwrite(path + '//' + str(i) + '.jpg', x)

for i in range(len(X_test)):
    x = X_test[i]
    y = y_test[i]
    path = val + str(y[0])
    x = cv2.resize(x, (224, 224), interpolation=cv2.INTER_CUBIC)
    if not os.path.exists(path):
        os.makedirs(path)
    cv2.imwrite(path + '//' + str(i) + '.jpg', x)
# Out:
# Using TensorFlow backend.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169009152/169001437 [==============================] - 6s 0us/step

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
"""
Train the MobileNet V2 model (https://github.com/xiaochus/MobileNetV2)
"""
import os
import sys
import argparse
import pandas as pd
import tensorflow as tf

from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping
from keras.layers import Conv2D, Reshape, Activation
from keras.models import Model

def generate(batch, size):
    """Data generation and augmentation

    # Arguments
        batch: Integer, batch size.
        size: Integer, image size.

    # Returns
        train_generator: train set generator
        validation_generator: validation set generator
        count1: Integer, number of train set.
        count2: Integer, number of test set.
    """

    #  Using the data Augmentation in traning data
    ptrain = './train'
    pval = './validation'

    datagen1 = ImageDataGenerator(
        rescale=1. / 255,
        shear_range=0.2,
        zoom_range=0.2,
        rotation_range=90,
        width_shift_range=0.2,
        height_shift_range=0.2,
        horizontal_flip=True)

    datagen2 = ImageDataGenerator(rescale=1. / 255)

    train_generator = datagen1.flow_from_directory(
        ptrain,
        target_size=(size, size),
        batch_size=batch,
        class_mode='categorical')

    validation_generator = datagen2.flow_from_directory(
        pval,
        target_size=(size, size),
        batch_size=batch,
        class_mode='categorical')

    count1 = 0
    for root, dirs, files in os.walk(ptrain):
        for each in files:
            count1 += 1

    count2 = 0
    for root, dirs, files in os.walk(pval):
        for each in files:
            count2 += 1

    return train_generator, validation_generator, count1, count2


def train(batch=64, epochs=20, num_classes=100, size=32):

    train_generator, validation_generator, count1, count2 = generate(batch, size)



    print("{} classes found".format(num_classes))

    model = MobileNetV2((size, size, 3), num_classes, True)
    # model = new_pruned_model
    opt = tf.keras.optimizers.Adam()
    # opt = tf.keras.optimizers.SGD(lr=1e-3, momentum=0.3, decay=0, nesterov=False)
    earlystop = tf.keras.callbacks.EarlyStopping(monitor='val_acc', patience=30, verbose=1, mode='auto')
    model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['acc'])

    hist = model.fit_generator(
        train_generator,
        validation_data=validation_generator,
        steps_per_epoch=count1 // batch,
        validation_steps=count2 // batch,
        epochs=epochs,
        callbacks=[earlystop])
    
    # model = MobileNetv2((size, size, 3), num_classes)
    # inp = Input(shape=(size, size, 3), batch_size=batch, dtype='float32')
    # model = Model((size, size, 3), MobileNetv2((size, size, 3),num_classes))

    # print(train_generator[-1], validation_generator[-1], count1, count2)
    # print(count1 // batch, count2 // batch)
    # # Optimizer = tf.keras.optimizers.Adam()
    # Optimizer = tf.keras.optimizers.SGD(lr=1e-3, momentum=0.3, decay=0, nesterov=False)
    # model.compile(loss=tf.keras.losses.categorical_crossentropy,
    #                   optimizer=Optimizer,
    #                   metrics=['accuracy'])
    # earlystop = EarlyStopping(monitor='val_acc', patience=30, verbose=1, mode='auto')
    
    # model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

    # hist = model.fit_generator(
    #     train_generator,
    #     validation_data=validation_generator,
    #     steps_per_epoch=count1 // batch,
    #     validation_steps=count2 // batch,
    #     epochs=epochs,
    #     callbacks=[earlystop])
    
    # hist = model.fit(
    #     train_generator,
    #     validation_data=validation_generator,
    #     steps_per_epoch=count1 // batch,
    #     validation_steps=count2 // batch,
    #     epochs=epochs,
    #     callbacks=[earlystop],
    #     use_multiprocessing=True)

    if not os.path.exists('model'):
        os.makedirs('model')

    df = pd.DataFrame.from_dict(hist.history)
    df.to_csv('model/hist.csv', encoding='utf-8', index=False)
    model.save_weights('model/weights.h5')

    return model, train_generator, validation_generator, count1, count2, batch

# if __name__ == '__main__':
#     main(sys.argv)

# %%
initial_model, train_generator, validation_generator, count1, count2, batch = train()
# Out:
# Found 50000 images belonging to 100 classes.
# Found 10000 images belonging to 100 classes.
# 100 classes found
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 16, 16, 32)   896         input[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 16, 16, 32)   128         conv2d[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    multiple             0           batch_normalization[0][0]
#                                                                  batch_normalization_1[0][0]
#                                                                  batch_normalization_2[0][0]
#                                                                  batch_normalization_4[0][0]
#                                                                  batch_normalization_5[0][0]
#                                                                  batch_normalization_7[0][0]
#                                                                  batch_normalization_8[0][0]
#                                                                  batch_normalization_10[0][0]
#                                                                  batch_normalization_11[0][0]
#                                                                  batch_normalization_13[0][0]
#                                                                  batch_normalization_14[0][0]
#                                                                  batch_normalization_16[0][0]
#                                                                  batch_normalization_17[0][0]
#                                                                  batch_normalization_19[0][0]
#                                                                  batch_normalization_20[0][0]
#                                                                  batch_normalization_22[0][0]
#                                                                  batch_normalization_23[0][0]
#                                                                  batch_normalization_25[0][0]
#                                                                  batch_normalization_26[0][0]
#                                                                  batch_normalization_28[0][0]
#                                                                  batch_normalization_29[0][0]
#                                                                  batch_normalization_31[0][0]
#                                                                  batch_normalization_32[0][0]
#                                                                  batch_normalization_34[0][0]
#                                                                  batch_normalization_35[0][0]
#                                                                  batch_normalization_37[0][0]
#                                                                  batch_normalization_38[0][0]
#                                                                  batch_normalization_40[0][0]
#                                                                  batch_normalization_41[0][0]
#                                                                  batch_normalization_43[0][0]
#                                                                  batch_normalization_44[0][0]
#                                                                  batch_normalization_46[0][0]
#                                                                  batch_normalization_47[0][0]
#                                                                  batch_normalization_49[0][0]
#                                                                  batch_normalization_50[0][0]
#                                                                  batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 32)   1056        re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 32)   128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d (DepthwiseConv (None, 16, 16, 32)   320         re_lu[1][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 32)   128         depthwise_conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 16, 16, 16)   528         re_lu[2][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 96)   1632        batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 96)   384         conv2d_3[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_1 (DepthwiseCo (None, 8, 8, 96)     960         re_lu[3][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 96)     384         depthwise_conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 8, 8, 24)     2328        re_lu[4][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 8, 8, 24)     96          conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 144)    3600        batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 8, 8, 144)    576         conv2d_5[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_2 (DepthwiseCo (None, 8, 8, 144)    1440        re_lu[5][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 8, 8, 144)    576         depthwise_conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 8, 8, 24)     3480        re_lu[6][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 8, 8, 24)     96          conv2d_6[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 8, 8, 24)     0           batch_normalization_9[0][0]
#                                                                  batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 8, 8, 144)    3600        add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 144)    576         conv2d_7[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_3 (DepthwiseCo (None, 4, 4, 144)    1440        re_lu[7][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 144)    576         depthwise_conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 4, 4, 32)     4640        re_lu[8][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 4, 4, 32)     128         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 4, 4, 192)    6336        batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 4, 4, 192)    768         conv2d_9[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_4 (DepthwiseCo (None, 4, 4, 192)    1920        re_lu[9][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 4, 4, 192)    768         depthwise_conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 4, 4, 32)     6176        re_lu[10][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 32)     128         conv2d_10[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 4, 4, 32)     0           batch_normalization_15[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 192)    6336        add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, 4, 192)    768         conv2d_11[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_5 (DepthwiseCo (None, 4, 4, 192)    1920        re_lu[11][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 192)    768         depthwise_conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 4, 4, 32)     6176        re_lu[12][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, 4, 32)     128         conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 4, 4, 32)     0           batch_normalization_18[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 4, 4, 192)    6336        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, 4, 192)    768         conv2d_13[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_6 (DepthwiseCo (None, 2, 2, 192)    1920        re_lu[13][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 2, 2, 192)    768         depthwise_conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 2, 2, 64)     12352       re_lu[14][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 2, 2, 64)     256         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 2, 2, 384)    24960       batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 2, 2, 384)    1536        conv2d_15[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_7 (DepthwiseCo (None, 2, 2, 384)    3840        re_lu[15][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 2, 2, 384)    1536        depthwise_conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 2, 2, 64)     24640       re_lu[16][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 2, 2, 64)     256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 2, 2, 64)     0           batch_normalization_24[0][0]
#                                                                  batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 2, 2, 384)    24960       add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 2, 2, 384)    1536        conv2d_17[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_8 (DepthwiseCo (None, 2, 2, 384)    3840        re_lu[17][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 2, 2, 384)    1536        depthwise_conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 2, 2, 64)     24640       re_lu[18][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 2, 2, 64)     256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 2, 2, 64)     0           batch_normalization_27[0][0]
#                                                                  add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 2, 2, 384)    24960       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 2, 2, 384)    1536        conv2d_19[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_9 (DepthwiseCo (None, 2, 2, 384)    3840        re_lu[19][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 2, 2, 384)    1536        depthwise_conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 2, 2, 64)     24640       re_lu[20][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 2, 2, 64)     256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 2, 2, 64)     0           batch_normalization_30[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 2, 2, 384)    24960       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 2, 2, 384)    1536        conv2d_21[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_10 (DepthwiseC (None, 2, 2, 384)    3840        re_lu[21][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 2, 2, 384)    1536        depthwise_conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 2, 2, 96)     36960       re_lu[22][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 2, 2, 96)     384         conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 2, 2, 576)    55872       batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 2, 2, 576)    2304        conv2d_23[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 2, 2, 576)    5760        re_lu[23][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 2, 2, 576)    2304        depthwise_conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 2, 2, 96)     55392       re_lu[24][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 2, 2, 96)     384         conv2d_24[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 2, 2, 96)     0           batch_normalization_36[0][0]
#                                                                  batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 2, 2, 576)    55872       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 2, 2, 576)    2304        conv2d_25[0][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 2, 2, 576)    5760        re_lu[25][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None,
# 781/781 [==============================] - 90s 116ms/step - loss: 3.8768 - acc: 0.0950 - val_loss: 3.7749 - val_acc: 0.1075
# Epoch 11/20
# 781/781 [==============================] - 90s 115ms/step - loss: 3.8227 - acc: 0.1010 - val_loss: 3.9108 - val_acc: 0.0865
# Epoch 12/20
# 781/781 [==============================] - 90s 115ms/step - loss: 3.8270 - acc: 0.1034 - val_loss: 3.9795 - val_acc: 0.0759
# Epoch 13/20
# 781/781 [==============================] - 89s 114ms/step - loss: 3.7757 - acc: 0.1090 - val_loss: 4.1173 - val_acc: 0.0617
# Epoch 14/20
# 781/781 [==============================] - 90s 115ms/step - loss: 3.7806 - acc: 0.1070 - val_loss: 3.6926 - val_acc: 0.1202
# Epoch 15/20
# 781/781 [==============================] - 89s 114ms/step - loss: 3.7057 - acc: 0.1190 - val_loss: 4.3275 - val_acc: 0.0679
# Epoch 16/20
# 781/781 [==============================] - 90s 115ms/step - loss: 3.6900 - acc: 0.1202 - val_loss: 4.1901 - val_acc: 0.0718
# Epoch 17/20
# 781/781 [==============================] - 90s 115ms/step - loss: 3.8504 - acc: 0.0980 - val_loss: 3.7355 - val_acc: 0.1146
# Epoch 18/20
# 781/781 [==============================] - 91s 116ms/step - loss: 3.7015 - acc: 0.1184 - val_loss: 4.1071 - val_acc: 0.0786
# Epoch 19/20
# 781/781 [==============================] - 90s 115ms/step - loss: 3.6658 - acc: 0.1242 - val_loss: 3.5695 - val_acc: 0.1371
# Epoch 20/20
# 781/781 [==============================] - 90s 115ms/step - loss: 3.6158 - acc: 0.1326 - val_loss: 3.9486 - val_acc: 0.1012

# %%
# from tensorflow.keras.utils import plot_model
# print(initial_model.summary())
# plot_model(initial_model, to_file='model.png', show_shapes=True)

# %% [markdown]
# # **Pruning**

# %%
import numpy as np
from tensorflow_model_optimization.sparsity import keras as sparsity


print(initial_model._is_graph_network)
# print(initial_model.Model)

print('Pruning')

device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  print(
      '\n\nThis error most likely means that this notebook is not '
      'configured to use a GPU.  Change this in Notebook Settings via the '
      'command palette (cmd/ctrl-shift-P) or the Edit menu.\n\n')
  raise SystemError('GPU device not found')

print('Found GPU at: {}'.format(device_name))

with tf.device('/device:GPU:0'):
  epochs = 4
  # num_train_samples = self.X_train.shape[0]
  end_step = np.ceil(1.0 * count1 / 64).astype(np.int32) * epochs
  print(end_step)

  new_pruning_params = {
        'pruning_schedule': sparsity.PolynomialDecay(initial_sparsity=0.50,
                                                    final_sparsity=0.90,
                                                    begin_step=0,
                                                    end_step=end_step,
                                                    frequency=100)
  }

  # new_pruning_params = {
  #       'pruning_schedule': sparsity.ConstantSparsity(0.75, begin_step=2000, frequency=100)
  # }
        # PolynomialDecay(initial_sparsity=0.2,
        #                                             final_sparsity=0.5,
        #                                             begin_step=0,
        #                                             end_step=end_step)

  new_pruned_model = sparsity.prune_low_magnitude(initial_model, **new_pruning_params)
  new_pruned_model.summary()

  new_pruned_model.compile(
      loss=tf.keras.losses.sparse_categorical_crossentropy,
      optimizer='adam',
      metrics=['accuracy'])


logdir = './'
print('Writing training logs to ' + logdir)

callbacks = [
    sparsity.UpdatePruningStep(),
    sparsity.PruningSummaries(log_dir=logdir, profile_batch=0)
]
# Out:
# True
# Pruning
# Found GPU at: /device:GPU:0
# 3128
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:183: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d (Pru (None, 16, 16, 32)   1762        input[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 16, 32)   129         prune_low_magnitude_conv2d[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_re_lu (Prun multiple             1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_1 (P (None, 16, 16, 32)   2082        prune_low_magnitude_re_lu[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 16, 32)   129         prune_low_magnitude_conv2d_1[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 16, 16, 32)   321         prune_low_magnitude_re_lu[1][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 16, 32)   129         prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_2 (P (None, 16, 16, 16)   1042        prune_low_magnitude_re_lu[2][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 16, 16)   65          prune_low_magnitude_conv2d_2[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_3 (P (None, 16, 16, 96)   3170        prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 16, 16, 96)   385         prune_low_magnitude_conv2d_3[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 8, 8, 96)     961         prune_low_magnitude_re_lu[3][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 8, 96)     385         prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_4 (P (None, 8, 8, 24)     4634        prune_low_magnitude_re_lu[4][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 8, 24)     97          prune_low_magnitude_conv2d_4[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_5 (P (None, 8, 8, 144)    7058        prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 8, 144)    577         prune_low_magnitude_conv2d_5[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 8, 8, 144)    1441        prune_low_magnitude_re_lu[5][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 8, 144)    577         prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_6 (P (None, 8, 8, 24)     6938        prune_low_magnitude_re_lu[6][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 8, 24)     97          prune_low_magnitude_conv2d_6[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_add (PruneL (None, 8, 8, 24)     1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_7 (P (None, 8, 8, 144)    7058        prune_low_magnitude_add[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 8, 8, 144)    577         prune_low_magnitude_conv2d_7[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 4, 4, 144)    1441        prune_low_magnitude_re_lu[7][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 4, 4, 144)    577         prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_8 (P (None, 4, 4, 32)     9250        prune_low_magnitude_re_lu[8][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 4, 4, 32)     129         prune_low_magnitude_conv2d_8[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_9 (P (None, 4, 4, 192)    12482       prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 4, 4, 192)    769         prune_low_magnitude_conv2d_9[0][0
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 4, 4, 192)    1921        prune_low_magnitude_re_lu[9][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 4, 4, 192)    769         prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_10 ( (None, 4, 4, 32)     12322       prune_low_magnitude_re_lu[10][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 4, 4, 32)     129         prune_low_magnitude_conv2d_10[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_1 (Prun (None, 4, 4, 32)     1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_11 ( (None, 4, 4, 192)    12482       prune_low_magnitude_add_1[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 4, 4, 192)    769         prune_low_magnitude_conv2d_11[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 4, 4, 192)    1921        prune_low_magnitude_re_lu[11][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 4, 4, 192)    769         prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_12 ( (None, 4, 4, 32)     12322       prune_low_magnitude_re_lu[12][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 4, 4, 32)     129         prune_low_magnitude_conv2d_12[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_2 (Prun (None, 4, 4, 32)     1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_add_1[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_13 ( (None, 4, 4, 192)    12482       prune_low_magnitude_add_2[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 4, 4, 192)    769         prune_low_magnitude_conv2d_13[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 2, 2, 192)    1921        prune_low_magnitude_re_lu[13][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 192)    769         prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_14 ( (None, 2, 2, 64)     24642       prune_low_magnitude_re_lu[14][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 64)     257         prune_low_magnitude_conv2d_14[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_15 ( (None, 2, 2, 384)    49538       prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 384)    1537        prune_low_magnitude_conv2d_15[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 2, 2, 384)    3841        prune_low_magnitude_re_lu[15][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 384)    1537        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_16 ( (None, 2, 2, 64)     49218       prune_low_magnitude_re_lu[16][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 64)     257         prune_low_magnitude_conv2d_16[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_3 (Prun (None, 2, 2, 64)     1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_17 ( (None, 2, 2, 384)    49538       prune_low_magnitude_add_3[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 384)    1537        prune_low_magnitude_conv2d_17[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 2, 2, 384)    3841        prune_low_magnitude_re_lu[17][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 384)    1537        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_18 ( (None, 2, 2, 64)     49218       prune_low_magnitude_re_lu[18][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 64)     257         prune_low_magnitude_conv2d_18[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_4 (Prun (None, 2, 2, 64)     1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_add_3[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_19 ( (None, 2, 2, 384)    49538       prune_low_magnitude_add_4[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 384)    1537        prune_low_magnitude_conv2d_19[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 2, 2, 384)    3841        prune_low_magnitude_re_lu[19][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 384)    1537        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_20 ( (None, 2, 2, 64)     49218       prune_low_magnitude_re_lu[20][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 64)     257         prune_low_magnitude_conv2d_20[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_5 (Prun (None, 2, 2, 64)     1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_add_4[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_21 ( (None, 2, 2, 384)    49538       prune_low_magnitude_add_5[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 384)    1537        prune_low_magnitude_conv2d_21[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 2, 2, 384)    3841        prune_low_magnitude_re_lu[21][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 384)    1537        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_22 ( (None, 2, 2, 96)     73826       prune_low_magnitude_re_lu[22][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 96)     385         prune_low_magnitude_conv2d_22[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_23 ( (None, 2, 2, 576)    111170      prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 576)    2305        prune_low_magnitude_conv2d_23[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 2, 2, 576)    5761        prune_low_magnitude_re_lu[23][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 576)    2305        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_24 ( (None, 2, 2, 96)     110690      prune_low_magnitude_re_lu[24][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 96)     385         prune_low_magnitude_conv2d_24[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_6 (Prun (None, 2, 2, 96)     1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_25 ( (None, 2, 2, 576)    111170      prune_low_magnitude_add_6[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 576)    2305        prune_low_magnitude_conv2d_25[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 2, 2, 576)    5761        prune_low_magnitude_re_lu[25][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 576)    2305        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_26 ( (None, 2, 2, 96)     110690      prune_low_magnitude_re_lu[26][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 96)     385         prune_low_magnitude_conv2d_26[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_7 (Prun (None, 2, 2, 96)     1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_add_6[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_27 ( (None, 2, 2, 576)    111170      prune_low_magnitude_add_7[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 2, 2, 576)    2305        prune_low_magnitude_conv2d_27[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 1, 1, 576)    5761        prune_low_magnitude_re_lu[27][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 1, 1, 576)    2305        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_28 ( (None, 1, 1, 160)    184482      prune_low_magnitude_re_lu[28][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 1, 1, 160)    641         prune_low_magnitude_conv2d_28[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_29 ( (None, 1, 1, 960)    308162      prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 1, 1, 960)    3841        prune_low_magnitude_conv2d_29[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 1, 1, 960)    9601        prune_low_magnitude_re_lu[29][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 1, 1, 960)    3841        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_30 ( (None, 1, 1, 160)    307362      prune_low_magnitude_re_lu[30][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 1, 1, 160)    641         prune_low_magnitude_conv2d_30[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_8 (Prun (None, 1, 1, 160)    1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_31 ( (None, 1, 1, 960)    308162      prune_low_magnitude_add_8[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 1, 1, 960)    3841        prune_low_magnitude_conv2d_31[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 1, 1, 960)    9601        prune_low_magnitude_re_lu[31][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 1, 1, 960)    3841        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_32 ( (None, 1, 1, 160)    307362      prune_low_magnitude_re_lu[32][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 1, 1, 160)    641         prune_low_magnitude_conv2d_32[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_add_9 (Prun (None, 1, 1, 160)    1           prune_low_magnitude_batch_normali
#                                                                  prune_low_magnitude_add_8[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_33 ( (None, 1, 1, 960)    308162      prune_low_magnitude_add_9[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 1, 1, 960)    3841        prune_low_magnitude_conv2d_33[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_depthwise_c (None, 1, 1, 960)    9601        prune_low_magnitude_re_lu[33][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 1, 1, 960)    3841        prune_low_magnitude_depthwise_con
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_34 ( (None, 1, 1, 320)    614722      prune_low_magnitude_re_lu[34][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 1, 1, 320)    1281        prune_low_magnitude_conv2d_34[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_35 ( (None, 1, 1, 1280)   820482      prune_low_magnitude_batch_normali
# __________________________________________________________________________________________________
# prune_low_magnitude_batch_norma (None, 1, 1, 1280)   5121        prune_low_magnitude_conv2d_35[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_global_aver (None, 1280)         1           prune_low_magnitude_re_lu[35][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_reshape (Pr (None, 1, 1, 1280)   1           prune_low_magnitude_global_averag
# __________________________________________________________________________________________________
# prune_low_magnitude_Dropout (Pr (None, 1, 1, 1280)   1           prune_low_magnitude_reshape[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_conv2d_36 ( (None, 1, 1, 100)    256102      prune_low_magnitude_Dropout[0][0]
# __________________________________________________________________________________________________
# prune_low_magnitude_final_activ (None, 1, 1, 100)    1           prune_low_magnitude_conv2d_36[0][
# __________________________________________________________________________________________________
# prune_low_magnitude_output (Pru (None, 100)          1           prune_low_magnitude_final_activat
# ==================================================================================================
# Total params: 4,659,044
# Trainable params: 2,370,148
# Non-trainable params: 2,288,896
# __________________________________________________________________________________________________
# Writing training logs to ./

# %%
new_pruned_model.fit(X_train, y_train,
          batch_size=batch,
          epochs=epochs,
          verbose=1,
          callbacks=callbacks,
          validation_data=(X_test, y_test))

score = new_pruned_model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

final_model = sparsity.strip_pruning(new_pruned_model)
final_model.summary()
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/4
# 49984/50000 [============================>.] - ETA: 0s - loss: 4.1234 - accuracy: 0.0718INFO:tensorflow:Summary name prune_low_magnitude_conv2d/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_1/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_1/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_2/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_2/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_3/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_3/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_4/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_4/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_5/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_5/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_6/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_6/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_7/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_7/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_8/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_8/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_9/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_9/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_10/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_10/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_11/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_11/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_12/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_12/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_13/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_13/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_14/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_14/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_15/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_15/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_16/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_16/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_17/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_17/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_18/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_18/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_19/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_19/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_20/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_20/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_21/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_21/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_22/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_22/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_23/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_23/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_24/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_24/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_25/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_25/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_26/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_26/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_27/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_27/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_28/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_28/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_29/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_29/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_30/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_30/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_31/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_31/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_32/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_32/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_33/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_33/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_34/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_34/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_35/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_35/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_36/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d_36/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_1/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_1/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_2/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_2/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_3/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_3/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_4/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_4/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_5/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_5/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_6/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_6/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_7/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_7/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_8/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_8/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_9/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_9/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_10/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_10/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_11/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_11/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_12/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_12/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_13/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_13/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_14/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_14/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_15/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_15/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_16/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_16/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_17/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_17/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_18/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_18/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_19/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_19/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_20/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_20/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_21/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_21/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_22/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_22/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_23/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_23/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_24/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_24/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_25/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_25/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_26/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_26/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_27/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_27/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_28/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_28/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_29/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_29/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_30/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_30/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_31/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_31/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_32/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_32/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_33/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_33/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_34/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_34/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_35/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_35/threshold_0/threshold instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d_36/threshold:0/threshold is illegal; using prune_low_magnitude_conv2d_36/threshold_0/threshold instead.
# 50000/50000 [==============================] - 105s 2ms/sample - loss: 4.1239 - accuracy: 0.0718 - val_loss: 3.8667 - val_accuracy: 0.0965
# Epoch 2/4
# 49984/50000 [============================>.] - ETA: 0s - loss: 3.7197 - accuracy: 0.1158INFO:tensorflow:Summary name prune_low_magnitude_conv2d/mask:0/sparsity is illegal; using prune_low_magnitude_conv2d/mask_0/sparsity instead.
# INFO:tensorflow:Summary name prune_low_magnitude_conv2d
0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 2, 2, 384)    1536        depthwise_conv2d_10[1][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 2, 2, 96)     36960       re_lu[58][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 2, 2, 96)     384         conv2d_22[1][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 2, 2, 576)    55872       batch_normalization_33[1][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 2, 2, 576)    2304        conv2d_23[1][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_11 (DepthwiseC (None, 2, 2, 576)    5760        re_lu[59][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 2, 2, 576)    2304        depthwise_conv2d_11[1][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 2, 2, 96)     55392       re_lu[60][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 2, 2, 96)     384         conv2d_24[1][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 2, 2, 96)     0           batch_normalization_36[1][0]
#                                                                  batch_normalization_33[1][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 2, 2, 576)    55872       add_6[1][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 2, 2, 576)    2304        conv2d_25[1][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_12 (DepthwiseC (None, 2, 2, 576)    5760        re_lu[61][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 2, 2, 576)    2304        depthwise_conv2d_12[1][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 2, 2, 96)     55392       re_lu[62][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 2, 2, 96)     384         conv2d_26[1][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 2, 2, 96)     0           batch_normalization_39[1][0]
#                                                                  add_6[1][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 2, 2, 576)    55872       add_7[1][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 2, 2, 576)    2304        conv2d_27[1][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_13 (DepthwiseC (None, 1, 1, 576)    5760        re_lu[63][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 1, 1, 576)    2304        depthwise_conv2d_13[1][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 1, 1, 160)    92320       re_lu[64][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 1, 1, 160)    640         conv2d_28[1][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 1, 1, 960)    154560      batch_normalization_42[1][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 1, 1, 960)    3840        conv2d_29[1][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_14 (DepthwiseC (None, 1, 1, 960)    9600        re_lu[65][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 1, 1, 960)    3840        depthwise_conv2d_14[1][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 1, 1, 160)    153760      re_lu[66][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 1, 1, 160)    640         conv2d_30[1][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 1, 1, 160)    0           batch_normalization_45[1][0]
#                                                                  batch_normalization_42[1][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 1, 1, 960)    154560      add_8[1][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 1, 1, 960)    3840        conv2d_31[1][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_15 (DepthwiseC (None, 1, 1, 960)    9600        re_lu[67][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 1, 1, 960)    3840        depthwise_conv2d_15[1][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 1, 1, 160)    153760      re_lu[68][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 1, 1, 160)    640         conv2d_32[1][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 1, 1, 160)    0           batch_normalization_48[1][0]
#                                                                  add_8[1][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 1, 1, 960)    154560      add_9[1][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 1, 1, 960)    3840        conv2d_33[1][0]
# __________________________________________________________________________________________________
# depthwise_conv2d_16 (DepthwiseC (None, 1, 1, 960)    9600        re_lu[69][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 1, 1, 960)    3840        depthwise_conv2d_16[1][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 1, 1, 320)    307520      re_lu[70][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 1, 1, 320)    1280        conv2d_34[1][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 1, 1, 1280)   410880      batch_normalization_51[1][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 1, 1, 1280)   5120        conv2d_35[1][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 1280)         0           re_lu[71][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 1, 1280)   0           global_average_pooling2d[1][0]
# __________________________________________________________________________________________________
# Dropout (Dropout)               (None, 1, 1, 1280)   0           reshape[1][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 1, 1, 100)    128100      Dropout[1][0]
# __________________________________________________________________________________________________
# final_activation (Activation)   (None, 1, 1, 100)    0           conv2d_36[1][0]
# __________________________________________________________________________________________________
# output (Reshape)                (None, 100)          0           final_activation[1][0]
# ==================================================================================================
# Total params: 2,404,324
# Trainable params: 2,370,148
# Non-trainable params: 34,176
# __________________________________________________________________________________________________

# %%
import numpy as np
names, params, percent = [] ,[], []
dash = '-' * 80
print(dash)
print('{:<20s}{:>40s}{:>12s}'.format('Name','Total Parameters','    Pruned %'))
print(dash)

for i, w in enumerate(final_model.get_weights()):
    print('{0:<40} {1:>10} {2:>18.3f}'.format(final_model.weights[i].name, w.size, np.sum(w == 0) / w.size * 100) )
    
    if(np.sum(w == 0) > 0):
      names.append(final_model.weights[i].name)
      params.append(w.size)
      percent.append(np.sum(w == 0))

print(params[0])
print(percent[0])
# Out:
# --------------------------------------------------------------------------------
# Name                                        Total Parameters    Pruned %
# --------------------------------------------------------------------------------
# conv2d/kernel:0                                 864             90.046
# conv2d/bias:0                                    32              0.000
# batch_normalization/gamma:0                      32              0.000
# batch_normalization/beta:0                       32              0.000
# batch_normalization/moving_mean:0                32              0.000
# batch_normalization/moving_variance:0            32              0.000
# conv2d_1/kernel:0                              1024             90.039
# conv2d_1/bias:0                                  32              0.000
# batch_normalization_1/gamma:0                    32              0.000
# batch_normalization_1/beta:0                     32              0.000
# batch_normalization_1/moving_mean:0              32              0.000
# batch_normalization_1/moving_variance:0          32              0.000
# depthwise_conv2d/depthwise_kernel:0             288              0.000
# depthwise_conv2d/bias:0                          32              0.000
# batch_normalization_2/gamma:0                    32              0.000
# batch_normalization_2/beta:0                     32              0.000
# batch_normalization_2/moving_mean:0              32              0.000
# batch_normalization_2/moving_variance:0          32              0.000
# conv2d_2/kernel:0                               512             90.039
# conv2d_2/bias:0                                  16              0.000
# batch_normalization_3/gamma:0                    16              0.000
# batch_normalization_3/beta:0                     16              0.000
# batch_normalization_3/moving_mean:0              16              0.000
# batch_normalization_3/moving_variance:0          16              0.000
# conv2d_3/kernel:0                              1536             89.974
# conv2d_3/bias:0                                  96              0.000
# batch_normalization_4/gamma:0                    96              0.000
# batch_normalization_4/beta:0                     96              0.000
# batch_normalization_4/moving_mean:0              96              0.000
# batch_normalization_4/moving_variance:0          96              0.000
# depthwise_conv2d_1/depthwise_kernel:0           864              0.000
# depthwise_conv2d_1/bias:0                        96              0.000
# batch_normalization_5/gamma:0                    96              0.000
# batch_normalization_5/beta:0                     96              0.000
# batch_normalization_5/moving_mean:0              96              0.000
# batch_normalization_5/moving_variance:0          96              0.000
# conv2d_4/kernel:0                              2304             90.017
# conv2d_4/bias:0                                  24              0.000
# batch_normalization_6/gamma:0                    24              0.000
# batch_normalization_6/beta:0                     24              0.000
# batch_normalization_6/moving_mean:0              24              0.000
# batch_normalization_6/moving_variance:0          24              0.000
# conv2d_5/kernel:0                              3456             89.988
# conv2d_5/bias:0                                 144              0.000
# batch_normalization_7/gamma:0                   144              0.000
# batch_normalization_7/beta:0                    144              0.000
# batch_normalization_7/moving_mean:0             144              0.000
# batch_normalization_7/moving_variance:0         144              0.000
# depthwise_conv2d_2/depthwise_kernel:0          1296              0.000
# depthwise_conv2d_2/bias:0                       144              0.000
# batch_normalization_8/gamma:0                   144              0.000
# batch_normalization_8/beta:0                    144              0.000
# batch_normalization_8/moving_mean:0             144              0.000
# batch_normalization_8/moving_variance:0         144              0.000
# conv2d_6/kernel:0                              3456             89.988
# conv2d_6/bias:0                                  24              0.000
# batch_normalization_9/gamma:0                    24              0.000
# batch_normalization_9/beta:0                     24              0.000
# batch_normalization_9/moving_mean:0              24              0.000
# batch_normalization_9/moving_variance:0          24              0.000
# conv2d_7/kernel:0                              3456             89.988
# conv2d_7/bias:0                                 144              0.000
# batch_normalization_10/gamma:0                  144              0.000
# batch_normalization_10/beta:0                   144              0.000
# batch_normalization_10/moving_mean:0            144              0.000
# batch_normalization_10/moving_variance:0        144              0.000
# depthwise_conv2d_3/depthwise_kernel:0          1296              0.000
# depthwise_conv2d_3/bias:0                       144              0.000
# batch_normalization_11/gamma:0                  144              0.000
# batch_normalization_11/beta:0                   144              0.000
# batch_normalization_11/moving_mean:0            144              0.000
# batch_normalization_11/moving_variance:0        144              0.000
# conv2d_8/kernel:0                              4608             89.996
# conv2d_8/bias:0                                  32              0.000
# batch_normalization_12/gamma:0                   32              0.000
# batch_normalization_12/beta:0                    32              0.000
# batch_normalization_12/moving_mean:0             32              0.000
# batch_normalization_12/moving_variance:0         32              0.000
# conv2d_9/kernel:0                              6144             90.007
# conv2d_9/bias:0                                 192              0.000
# batch_normalization_13/gamma:0                  192              0.000
# batch_normalization_13/beta:0                   192              0.000
# batch_normalization_13/moving_mean:0            192              0.000
# batch_normalization_13/moving_variance:0        192              0.000
# depthwise_conv2d_4/depthwise_kernel:0          1728              0.000
# depthwise_conv2d_4/bias:0                       192              0.000
# batch_normalization_14/gamma:0                  192              0.000
# batch_normalization_14/beta:0                   192              0.000
# batch_normalization_14/moving_mean:0            192              0.000
# batch_normalization_14/moving_variance:0        192              0.000
# conv2d_10/kernel:0                             6144             90.007
# conv2d_10/bias:0                                 32              0.000
# batch_normalization_15/gamma:0                   32              0.000
# batch_normalization_15/beta:0                    32              0.000
# batch_normalization_15/moving_mean:0             32              0.000
# batch_normalization_15/moving_variance:0         32              0.000
# conv2d_11/kernel:0                             6144             90.007
# conv2d_11/bias:0                                192              0.000
# batch_normalization_16/gamma:0                  192              0.000
# batch_normalization_16/beta:0                   192              0.000
# batch_normalization_16/moving_mean:0            192              0.000
# batch_normalization_16/moving_variance:0        192              0.000
# depthwise_conv2d_5/depthwise_kernel:0          1728              0.000
# depthwise_conv2d_5/bias:0                       192              0.000
# batch_normalization_17/gamma:0                  192              0.000
# batch_normalization_17/beta:0                   192              0.000
# batch_normalization_17/moving_mean:0            192              0.000
# batch_normalization_17/moving_variance:0        192              0.000
# conv2d_12/kernel:0                             6144             90.007
# conv2d_12/bias:0                                 32              0.000
# batch_normalization_18/gamma:0                   32              0.000
# batch_normalization_18/beta:0                    32              0.000
# batch_normalization_18/moving_mean:0             32              0.000
# batch_normalization_18/moving_variance:0         32              0.000
# conv2d_13/kernel:0                             6144             90.007
# conv2d_13/bias:0                                192              0.000
# batch_normalization_19/gamma:0                  192              0.000
# batch_normalization_19/beta:0                   192              0.000
# batch_normalization_19/moving_mean:0            192              0.000
# batch_normalization_19/moving_variance:0        192              0.000
# depthwise_conv2d_6/depthwise_kernel:0          1728              0.000
# depthwise_conv2d_6/bias:0                       192              0.000
# batch_normalization_20/gamma:0                  192              0.000
# batch_normalization_20/beta:0                   192              0.000
# batch_normalization_20/moving_mean:0            192              0.000
# batch_normalization_20/moving_variance:0        192              0.000
# conv2d_14/kernel:0                            12288             89.998
# conv2d_14/bias:0                                 64              0.000
# batch_normalization_21/gamma:0                   64              0.000
# batch_normalization_21/beta:0                    64              0.000
# batch_normalization_21/moving_mean:0             64              0.000
# batch_normalization_21/moving_variance:0         64              0.000
# conv2d_15/kernel:0                            24576             89.998
# conv2d_15/bias:0                                384              0.000
# batch_normalization_22/gamma:0                  384              0.000
# batch_normalization_22/beta:0                   384              0.000
# batch_normalization_22/moving_mean:0            384              0.000
# batch_normalization_22/moving_variance:0        384              0.000
# depthwise_conv2d_7/depthwise_kernel:0          3456              0.000
# depthwise_conv2d_7/bias:0                       384              0.000
# batch_normalization_23/gamma:0                  384              0.000
# batch_normalization_23/beta:0                   384              0.000
# batch_normalization_23/moving_mean:0            384              0.000
# batch_normalization_23/moving_variance:0        384              0.000
# conv2d_16/kernel:0                            24576             89.998
# conv2d_16/bias:0                                 64              0.000
# batch_normalization_24/gamma:0                   64              0.000
# batch_normalization_24/beta:0                    64              0.000
# batch_normalization_24/moving_mean:0             64              0.000
# batch_normalization_24/moving_variance:0         64              0.000
# conv2d_17/kernel:0                            24576             89.998
# conv2d_17/bias:0                                384              0.000
# batch_normalization_25/gamma:0                  384              0.000
# batch_normalization_25/beta:0                   384              0.000
# batch_normalization_25/moving_mean:0            384              0.000
# batch_normalization_25/moving_variance:0        384              0.000
# depthwise_conv2d_8/depthwise_kernel:0          3456              0.000
# depthwise_conv2d_8/bias:0                       384              0.000
# batch_normalization_26/gamma:0                  384              0.000
# batch_normalization_26/beta:0                   384              0.000
# batch_normalization_26/moving_mean:0            384              0.000
# batch_normalization_26/moving_variance:0        384              0.000
# conv2d_18/kernel:0                            24576             89.998
# conv2d_18/bias:0                                 64              0.000
# batch_normalization_27/gamma:0                   64              0.000
# batch_normalization_27/beta:0                    64              0.000
# batch_normalization_27/moving_mean:0             64              0.000
# batch_normalization_27/moving_variance:0         64              0.000
# conv2d_19/kernel:0                            24576             89.998
# conv2d_19/bias:0                                384              0.000
# batch_normalization_28/gamma:0                  384              0.000
# batch_normalization_28/beta:0                   384              0.000
# batch_normalization_28/moving_mean:0            384              0.000
# batch_normalization_28/moving_variance:0        384              0.000
# depthwise_conv2d_9/depthwise_kernel:0          3456              0.000
# depthwise_conv2d_9/bias:0                       384              0.000
# batch_normalization_29/gamma:0                  384              0.000
# batch_normalization_29/beta:0                   384              0.000
# batch_normalization_29/moving_mean:0            384              0.000
# batch_normalization_29/moving_variance:0        384              0.000
# conv2d_20/kernel:0                            24576             89.998
# conv2d_20/bias:0                                 64              0.000
# batch_normalization_30/gamma:0                   64              0.000
# batch_normalization_30/beta:0                    64              0.000
# batch_normalization_30/moving_mean:0             64              0.000
# batch_normalization_30/moving_variance:0         64              0.000
# conv2d_21/kernel:0                            24576             89.998
# conv2d_21/bias:0                                384              0.000
# batch_normalization_31/gamma:0                  384              0.000
# batch_normalization_31/beta:0                   384              0.000
# batch_normalization_31/moving_mean:0            384              0.000
# batch_normalization_31/moving_variance:0        384              0.000
# depthwise_conv2d_10/depthwise_kernel:0         3456              0.000
# depthwise_conv2d_10/bias:0                      384              0.000
# batch_normalization_32/gamma:0                  384              0.000
# batch_normalization_32/beta:0                   384              0.000
# batch_normalization_32/moving_mean:0            384              0.000
# batch_normalization_32/moving_variance:0        384              0.000
# conv2d_22/kernel:0                            36864             90.001
# conv2d_22/bias:0                                 96              0.000
# batch_normalization_33/gamma:0                   96              0.000
# batch_normalization_33/beta:0                    96              0.000
# batch_normalization_33/moving_mean:0             96              0.000
# batch_normalization_33/moving_variance:0         96              0.000
# conv2d_23/kernel:0                            55296             89.999
# conv2d_23/bias:0                                576              0.000
# batch_normalization_34/gamma:0                  576              0.000
# batch_normalization_34/beta:0                   576              0.000
# batch_normalization_34/moving_mean:0            576              0.000
# batch_normalization_34/moving_variance:0        576              0.000
# depthwise_conv2d_11/depthwise_kernel:0         5184              0.000
# depthwise_conv2d_11/bias:0                      576              0.000
# batch_normalization_35/gamma:0                  576              0.000
# batch_normalization_35/beta:0                   576              0.000
# batch_normalization_35/moving_mean:0            576              0.000
# batch_normalization_35/moving_variance:0        576              0.000
# conv2d_24/kernel:0                            55296             89.999
# conv2d_24/bias:0                                 96              0.000
# batch_normalization_36/gamma:0                   96              0.000
# batch_normalization_36/beta:0                    96              0.000
# batch_normalization_36/moving_mean:0             96              0.000
# batch_normalization_36/moving_variance:0         96              0.000
# conv2d_25/kernel:0                            55296             89.999
# conv2d_25/bias:0                                576              0.000
# batch_normalization_37/gamma:0                  576              0.000
# batch_normalization_37/beta:0                   576              0.000
# batch_normalization_37/moving_mean:0            576              0.000
# batch_normalization_37/moving_variance:0        576              0.000
# depthwise_conv2d_12/depthwise_kernel:0         5184              0.000
# depthwise_conv2d_12/bias:0                      576              0.000
# batch_normalization_38/gamma:0                  576              0.000
# batch_normalization_38/beta:0                   576              0.000
# batch_normalization_38/moving_mean:0            576              0.000
# batch_normalization_38/moving_variance:0        576              0.000
# conv2d_26/kernel:0                            55296             89.999
# conv2d_26/bias:0                                 96              0.000
# batch_normalization_39/gamma:0                   96              0.000
# batch_normalization_39/beta:0                    96              0.000
# batch_normalization_39/moving_mean:0             96              0.000
# batch_normalization_39/moving_variance:0         96              0.000
# conv2d_27/kernel:0                            55296             89.999
# conv2d_27/bias:0                                576              0.000
# batch_normalization_40/gamma:0                  576              0.000
# batch_normalization_40/beta:0                   576              0.000
# batch_normalization_40/moving_mean:0            576              0.000
# batch_normalization_40/moving_variance:0        576              0.000
# depthwise_conv2d_13/depthwise_kernel:0         5184              0.000
# depthwise_conv2d_13/bias:0                      576              0.000
# batch_normalization_41/gamma:0                  576              0.000
# batch_normalization_41/beta:0                   576              0.000
# batch_normalization_41/moving_mean:0            576              0.000
# batch_normalization_41/moving_variance:0        576              0.000
# conv2d_28/kernel:0                            92160             90.000
# conv2d_28/bias:0                                160              0.000
# batch_normalization_42/gamma:0                  160              0.000
# batch_normalization_42/beta:0                   160              0.000
# batch_normalization_42/moving_mean:0            160              0.000
# batch_normalization_42/moving_variance:0        160              0.000
# conv2d_29/kernel:0                           153600             90.000
# conv2d_29/bias:0                                960              0.000
# batch_normalization_43/gamma:0                  960              0.000
# batch_normalization_43/beta:0                   960              0.000
# batch_normalization_43/moving_mean:0            960              0.000
# batch_normalization_43/moving_variance:0        960              0.000
# depthwise_conv2d_14/depthwise_kernel:0         8640              0.000
# depthwise_conv2d_14/bias:0                      960              0.000
# batch_normalization_44/gamma:0                  960              0.000
# batch_normalization_44/beta:0                   960              0.000
# batch_normalization_44/moving_mean:0            960              0.000
# batch_normalization_44/moving_variance:0        960              0.000
# conv2d_30/kernel:0                           153600             90.000
# conv2d_30/bias:0                                160              0.000
# batch_normalization_45/gamma:0                  160              0.000
# batch_normalization_45/beta:0                   160              0.000
# batch_normalization_45/moving_mean:0            160              0.000
# batch_normalization_45/moving_variance:0        160              0.000
# conv2d_31/kernel:0                           153600             90.000
# conv2d_31/bias:0                                960              0.000
# batch_normalization_46/gamma:0                  960              0.000
# batch_normalization_46/beta:0                   960              0.000
# batch_normalization_46/moving_mean:0            960              0.000
# batch_normalization_46/moving_variance:0        960              0.000
# depthwise_conv2d_15/depthwise_kernel:0         8640              0.000
# depthwise_conv2d_15/bias:0                      960              0.000
# batch_normalization_47/gamma:0                  960              0.000
# batch_normalization_47/beta:0                   960              0.000
# batch_normalization_47/moving_mean:0            960              0.000
# batch_normalization_47/moving_variance:0        960              0.000
# conv2d_32/kernel:0                           153600             90.000
# conv2d_32/bias:0                                160              0.000
# batch_normalization_48/gamma:0                  160              0.000
# batch_normalization_48/beta:0                   160              0.000
# batch_normalization_48/moving_mean:0            160              0.000
# batch_normalization_48/moving_variance:0        160              0.000
# conv2d_33/kernel:0                           153600             90.000
# conv2d_33/bias:0                                960              0.000
# batch_normalization_49/gamma:0                  960              0.000
# batch_normalization_49/beta:0                   960              0.000
# batch_normalization_49/moving_mean:0            960              0.000
# batch_normalization_49/moving_variance:0        960              0.000
# depthwise_conv2d_16/depthwise_kernel:0         8640              0.000
# depthwise_conv2d_16/bias:0                      960              0.000
# batch_normalization_50/gamma:0                  960              0.000
# batch_normalization_50/beta:0                   960              0.000
# batch_normalization_50/moving_mean:0            960              0.000
# batch_normalization_50/moving_variance:0        960              0.000
# conv2d_34/kernel:0                           307200             90.000
# conv2d_34/bias:0                                320              0.000
# batch_normalization_51/gamma:0                  320              0.000
# batch_normalization_51/beta:0                   320              0.000
# batch_normalization_51/moving_mean:0            320              0.000
# batch_normalization_51/moving_variance:0        320              0.000
# conv2d_35/kernel:0                           409600             90.000
# conv2d_35/bias:0                               1280              0.000
# batch_normalization_52/gamma:0                 1280              0.000
# batch_normalization_52/beta:0                  1280              0.000
# batch_normalization_52/moving_mean:0           1280              0.000
# batch_normalization_52/moving_variance:0       1280              0.000
# conv2d_36/kernel:0                           128000             90.000
# conv2d_36/bias:0                                100              0.000
# 864
# 778

# %%
import plotly.graph_objects as go

fig = go.Figure()
fig.add_trace(go.Bar(x=names,
                y=params,
                name='Total Parameters',
                marker_color='rgb(55, 83, 109)'
                ))
fig.add_trace(go.Bar(x=names,
                y=percent,
                name='Pruned Parameters',
                marker_color='rgb(26, 118, 255)'
                ))

fig.update_layout(
    title='MobilenetV2 Pruned Parameters',
    xaxis_tickfont_size=14,
    yaxis=dict(
        title='Parameters',
        titlefont_size=16,
        tickfont_size=14,
    ),
    legend=dict(
        x=0,
        y=1.0,
        bgcolor='rgba(255, 255, 255, 0)',
        bordercolor='rgba(255, 255, 255, 0)'
    ),
    barmode='group',
    bargap=0.15, # gap between bars of adjacent location coordinates.
    bargroupgap=0.1 # gap between bars of the same location coordinate.
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="
legend": {"bgcolor": "rgba(255, 255, 255, 0)", "bordercolor": "rgba(255, 255, 255, 0)", "x": 0, "y": 1.0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scat ...

# %%
# Out:
# Size of the original model after compression: 2.26 Mb
# Size of the pruned model after compression: 2.25 Mb

# %% [markdown]
# **Quantization**

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(final_model)

converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]

tflite_quant_model = converter.convert()

tflite_quant_model_file = '/tmp/sparse_mnist_quant.tflite'
with open(tflite_quant_model_file, 'wb') as f:
  f.write(tflite_quant_model)

# %%
import zipfile 

# models = [[initial_model,'initial_model']
#           ,[final_model,'final_model']
#           ,[new_pruned_model,'new_pruned_model']]
models = [[final_model,'final_model']]
size_before = []
size_after = []
for i in models:
  print(i[1])

  tf.keras.models.save_model(i[0], './'+i[1]+'.h5', 
                          include_optimizer=False)

  print("Size of the pruned model before compression: %.4f Mb" 
        % (os.path.getsize('./'+i[1]+'.h5') / float(2**20)))
  size_before.append(os.path.getsize('./'+i[1]+'.h5') / float(2**20))
  with zipfile.ZipFile('./'+i[1]+'.zip', 'w', compression=zipfile.ZIP_DEFLATED) as f:
    f.write('./'+i[1]+'.h5')
  
  print("Size of the pruned model after compression: %.4f Mb" 
        % (os.path.getsize('./'+i[1]+'.zip') / float(2**20)))
  size_after.append(os.path.getsize('./'+i[1]+'.zip') / float(2**20))
  

import tempfile
_, zip_tflite = tempfile.mkstemp('.zip')
with zipfile.ZipFile(zip_tflite, 'w', compression=zipfile.ZIP_DEFLATED) as f:
  f.write(tflite_quant_model_file)
print("Size of the tflite quantized model before compression: %.2f Mb" 
      % (os.path.getsize(tflite_quant_model_file) / float(2**20)))
size_before.append(os.path.getsize(tflite_quant_model_file) / float(2**20))
print("Size of the tflite quantized model after compression: %.2f Mb" 
      % (os.path.getsize(zip_tflite) / float(2**20)))
size_after.append(os.path.getsize(zip_tflite) / float(2**20))
# Out:
# final_model
# Size of the pruned model before compression: 9.5953 Mb
# Size of the pruned model after compression: 2.2219 Mb
# Size of the tflite quantized model before compression: 2.31 Mb
# Size of the tflite quantized model after compression: 0.52 Mb

# %%
import plotly.graph_objects as go

months = ['Pruned', 'Quantized']

fig = go.Figure()
fig.add_trace(go.Bar(
    x=months,
    y=size_before,
    name='Before',
    marker_color='indianred'
))
fig.add_trace(go.Bar(
    x=months,
    y=size_after,
    name='After',
    marker_color='lightsalmon'
))

# Here we modify the tickangle of the xaxis, resulting in rotated labels.
fig.update_layout(
    yaxis=dict(
        title='Size (MB)',
        titlefont_size=16,
        tickfont_size=14,
    ),
    barmode='group', xaxis_tickangle=-45)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1502674b-8e9e-4243-907a-fd81a68f45fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1502674b-8e9e-4243-907a-fd81a68f45fb")) {
#                     Plotly.newPlot(
#                         '1502674b-8e9e-4243-907a-fd81a68f45fb',
#                         [{"marker": {"color": "indianred"}, "name": "Before", "type": "bar", "x": ["Pruned", "Quantized"], "y": [9.595252990722656, 2.3095855712890625]}, {"marker": {"color": "lightsalmon"}, "name": "After", "type": "bar", "x": ["Pruned", "Quantized"], "y": [2.2219467163085938, 0.5196771621704102]}],
#                         {"barmode": "group", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary": [{"mark ...

# %%
# Out:
# Size of the tflite model before compression: 2.31 Mb
# Size of the tflite model after compression: 0.52 Mb
